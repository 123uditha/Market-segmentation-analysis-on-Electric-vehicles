# %% [markdown]
# **Importing libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %% [markdown]
# **Featching Datasets**

# %%
#Dataset1
DF1 = "C:\\Users\\dell\\Downloads\\EVStats.csv"
df1 = pd.read_csv(DF1)
df1.head()
# Out:
#    Sl. No                      State  \
# 0       1                  Meghalaya
# 1       2                   Nagaland
# 2       3                    Manipur
# 3       4                    Tripura
# 4       5  Andaman & Nicobar islands
#
#    Two Wheelers (Category L1 & L2 as per Central Motor Vehicles Rules  \
# 0                                                  0
# 1                                                  0
# 2                                                 16
# 3                                                 28
# 4                                                  0
#
#    Two Wheelers (Category L2 (CMVR))  \
# 0                                  0
# 1                                 20
# 2                                  8
# 3                                  9
# 4                                  0
#
#    Two Wheelers (Max power not exceeding 250 Watts)  \
# 0                                                 0
# 1                                                 3
# ...

# %%
df1.tail()
# Out:
#     Sl. No          State  \
# 25      26          Delhi
# 26      27        Haryana
# 27      28  Uttar Pradesh
# 28      29        Gujarat
# 29      30    Maharashtra
#
#     Two Wheelers (Category L1 & L2 as per Central Motor Vehicles Rules  \
# 25                                               1395
# 26                                               3162
# 27                                               2954
# 28                                               7182
# 29                                               2630
#
#     Two Wheelers (Category L2 (CMVR))  \
# 25                                251
# 26                               1504
# 27                               2355
# 28                                217
# 29                               2097
#
#     Two Wheelers (Max power not exceeding 250 Watts)  \
# 25                                              5018
# 26                                             13908
# 27                                             15199
# ...

# %%
#Dataset2
DF2 = "C:\\Users\\dell\\Downloads\\Buying.csv"
df2 = pd.read_csv(DF2)
df2.head()
# Out:
#    Age Profession Marrital Status      Education  No of Dependents  \
# 0   27   Salaried          Single  Post Graduate                 0
# 1   35   Salaried         Married  Post Graduate                 2
# 2   45   Business         Married       Graduate                 4
# 3   41   Business         Married  Post Graduate                 3
# 4   31   Salaried         Married  Post Graduate                 2
#
#   Personal loan House Loan Wife Working   Salary  Wife Salary  Total Salary  \
# 0           Yes         No           No   800000            0        800000
# 1           Yes        Yes          Yes  1400000       600000       2000000
# 2           Yes        Yes           No  1800000            0       1800000
# 3            No         No          Yes  1600000       600000       2200000
# 4           Yes         No          Yes  1800000       800000       2600000
#
#      Make    Price
# 0     i20   800000
# 1    Ciaz  1000000
# 2  Duster  1200000
# 3    City  1200000
# ...

# %% [markdown]
# **Information of both datasets**

# %%
print("Dataset 1 -------------------------->")
df1.info()
print("Dataset 2 -------------------------->")
df2.info()
# Out:
# Dataset 1 -------------------------->
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 10 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Sl. No                                                              30 non-null     int64
#  1   State                                                               30 non-null     object
#  2   Two Wheelers (Category L1 & L2 as per Central Motor Vehicles Rules  30 non-null     int64
#  3   Two Wheelers (Category L2 (CMVR))                                   30 non-null     int64
#  4   Two Wheelers (Max power not exceeding 250 Watts)                    30 non-null     int64
#  5   Three Wheelers (Category L5 slow speed as per CMVR)                 30 non-null     int64
# ...

# %% [markdown]
# **Finding missing values**

# %%
d1 = df1.isnull().sum()
d2 = df2.isnull().sum()
print("DF1:-----------------------> ", d1)
print("DF2:------------------------------> ", d2)
# Out:
# DF1:----------------------->  Sl. No                                                                0
# State                                                                 0
# Two Wheelers (Category L1 & L2 as per Central Motor Vehicles Rules    0
# Two Wheelers (Category L2 (CMVR))                                     0
# Two Wheelers (Max power not exceeding 250 Watts)                      0
# Three Wheelers (Category L5 slow speed as per CMVR)                   0
# Three Wheelers (Category L5 as per CMVR)                              0
# Passenger Cars (Category M1 as per CMVR)                              0
# Buses                                                                 0
# Total in state                                                        0
# dtype: int64
# DF2:------------------------------>  Age                 0
# Profession          0
# Marrital Status     0
# Education           0
# No of Dependents    0
# Personal loan       0
# House Loan          0
# ...

# %% [markdown]
# **Finding duplicate values**

# %%
d1 = df1.duplicated().sum()
d2 = df2.duplicated().sum()
print("Dataset1 ---------------------->", d1)
print("Dataset2 ---------------------->", d2)
# Out:
# Dataset1 ----------------------> 0
# Dataset2 ----------------------> 0

# %% [markdown]
# **Exploratory data analysis**

# %%
#Shape of datasets
print("DF1 shape: ", df1.shape)
print("DF2 shape: ", df2.shape)
# Out:
# DF1 shape:  (30, 10)
# DF2 shape:  (99, 13)

# %% [markdown]
# **Descriptive Statistics**

# %%
d1 = df1.describe().T
d2 = df2.describe().T
display("Dataset1 --------------->", d1, "Dataset2 ----------------------->", d2)
# Out:
# 'Dataset1 --------------->'
#                                                     count         mean  \
# Sl. No                                               30.0    15.500000
# Two Wheelers (Category L1 & L2 as per Central M...   30.0   918.300000
# Two Wheelers (Category L2 (CMVR))                    30.0   468.966667
# Two Wheelers (Max power not exceeding 250 Watts)     30.0  3751.266667
# Three Wheelers (Category L5 slow speed as per C...   30.0    12.966667
# Three Wheelers (Category L5 as per CMVR)             30.0    24.000000
# Passenger Cars (Category M1 as per CMVR)             30.0  3519.033333
# Buses                                                30.0     0.900000
# Total in state                                       30.0  8695.433333
#
#                                                             std  min     25%  \
# Sl. No                                                 8.803408  1.0    8.25
# ...

# %% [markdown]
# **Analysing dataset 1**

# %% [markdown]
# **Analysing Buses**

# %%
#Analysing buses in states
sns.barplot(x = 'Buses', y = 'State', data = df1, color = "gold")
plt.xlabel('Two Wheelers')
plt.ylabel('States')
plt.title('Analysing Buses')
plt.show()

# %% [markdown]
# **Analysing Three Wheelers**

# %%
#Analysing no.of hree wheelers 
sns.barplot(x = 'Three Wheelers (Category L5 slow speed as per CMVR)', y = 'State', data = df1, color = "Purple")
plt.title("Analysing Three Wheelers in Indian States")
plt.xlabel("Three wheelers EV")
plt.ylabel("Indian Sates")
plt.show()

# %% [markdown]
# **Analysing Two Wheelers**

# %%
#Analysing no.of two wheelers 
sns.barplot(x = 'Two Wheelers (Category L1 & L2 as per Central Motor Vehicles Rules', y = 'State', data = df1, color = "orange")
plt.title("Analysing Two Wheelers in Indian States")
plt.xlabel("Two wheelers of L1 & L2 category")
plt.ylabel("States")
plt.show()

# %% [markdown]
# **Analysing Cars**

# %%
#Analysing Passenger cars
sns.pointplot(data =df1, x = "Passenger Cars (Category M1 as per CMVR)", y = "State", color = 'Brown')
plt.xlabel("Cars")
plt.ylabel("States")
plt.title("Analysing Passenger cars")
plt.show()

# %% [markdown]
# **Analysing Two Wheelers power not exceeding 250 watt**

# %%
sns.pointplot(data = df1, x = "Two Wheelers (Max power not exceeding 250 Watts)", y = "State", color = 'Brown')
plt.xlabel("Two wheelers")
plt.ylabel("States")
plt.title("Two wheelers power not exceeding 250  watt")
plt.show()

# %% [markdown]
# **Analysing Dataset 2**

# %%
sns.barplot(x = "Age", y = "Make", data = df2, color = 'Gold')
plt.xlabel("Age")
plt.ylabel("Living")
plt.title("Average people living in.......")
plt.show()

# %% [markdown]
# **Analysing vehicle prices**

# %%
sns.pointplot(x = "Make", y = "Price", data = df2, color = 'gold')
plt.title("Vehicle vs Price")
plt.xlabel("Vehicle")
plt.ylabel("Price")
plt.show()

# %% [markdown]
# **Salary distributed by profession**

# %%
grouped_df = df.groupby('Profession')['Salary'].sum()

# Create the pie chart
plt.figure(figsize=(8, 6))
plt.pie(grouped_df, labels=grouped_df.index, autopct='%1.1f%%', startangle=90)
plt.title('Salary Distribution by Profession')
plt.show()

# %% [markdown]
# **Analysing no of dependents for a salaried person**

# %%
sns.barplot(x = "Age", y = "No of Dependents", data = df2, color = 'Brown')
plt.title("No.of dependents of a average salaried person")
plt.xlabel("Age")
plt.ylabel("No of dependents")
plt.show()

# %% [markdown]
# **Analysing salaries**

# %%
sns.barplot(x = "Age", y = "Total Salary", data = df2, color = 'brown')
plt.title("Analysing salaries")
plt.xlabel("Age")
plt.ylabel("Salaries")
plt.show()

# %% [markdown]
# **Corelation between dataset 2**

# %%
s = df2.select_dtypes(include="number").corr()
plt.figure(figsize=(9,10))
sns.heatmap(s, annot = True)
plt.title("Correlation map")
plt.show()

# %% [markdown]
# **Correaltion between dataset 1**

# %%
s = df1.select_dtypes(include="number").corr()
plt.figure(figsize=(9,9))
sns.heatmap(s, annot = True)
plt.title("Correlation map")
plt.show()

# %% [markdown]
# **Encoding for dataset 1**

# %%
categorical_columns = df1.select_dtypes(include=['object']).columns
for col in categorical_columns:
    df1[col], uniques = pd.factorize(df1[col])
    print(f"Column: {col}")
    print(f"Mapping: {dict(enumerate(uniques))}\n")
df1.to_csv('ev_encoded.csv', index=False)
print("Encoded dataset saved as 'ev_encoded.csv'.")
# Out:
# Encoded dataset saved as 'ev_encoded.csv'.

# %% [markdown]
# **Segment extraction for daaset 1**

# %%
data = df1
kmeans = KMeans(n_clusters=4, random_state=0)
kmeans.fit(data)
cluster_1 = data[kmeans.labels_ == 0]
cluster_2 = data[kmeans.labels_ == 1]
cluster_3 = data[kmeans.labels_ == 2]
cluster_4 = data[kmeans.labels_ == 3]

print("Cluster 1:", cluster_1)
print("Cluster 2:", cluster_2)
print("Cluster 3:", cluster_3)
print("Cluster 4:", cluster_4)
# Out:
# Cluster 1:     Sl. No  State  \
# 16      17     16
# 17      18     17
# 18      19     18
# 19      20     19
# 20      21     20
# 21      22     21
#
#     Two Wheelers (Category L1 & L2 as per Central Motor Vehicles Rules  \
# 16                                                503
# 17                                                698
# 18                                                535
# 19                                                431
# 20                                                432
# 21                                                784
#
#     Two Wheelers (Category L2 (CMVR))  \
# 16                                378
# 17                                300
# 18                                711
# 19                                692
# 20                                 78
# 21                               1104
#
#     Two Wheelers (Max power not exceeding 250 Watts)  \
# 16                                              2904
# ...

# %% [markdown]
# **Encoding for dataset 2**

# %%
categorical_columns = df2.select_dtypes(include=['object']).columns
for col in categorical_columns:
    df2[col], uniques = pd.factorize(df2[col])
    print(f"Column: {col}")
    print(f"Mapping: {dict(enumerate(uniques))}\n")
df2.to_csv('stats_encoded.csv', index=False)
print("Encoded dataset saved as 'stats_encoded.csv'.")
# Out:
# Encoded dataset saved as 'stats_encoded.csv'.

# %% [markdown]
# **Segment extraction for dataset 2**

# %%
 data = df2
kmeans = KMeans(n_clusters=4, random_state=0)
kmeans.fit(data)
cluster_1 = data[kmeans.labels_ == 0]
cluster_2 = data[kmeans.labels_ == 1]
cluster_3 = data[kmeans.labels_ == 2]
cluster_4 = data[kmeans.labels_ == 3]

print("Cluster 1:", cluster_1)
print("Cluster 2:", cluster_2)
print("Cluster 3:", cluster_3)
print("Cluster 4:", cluster_4)
# Out:
# Cluster 1:     Age  Profession  Marrital Status  Education  No of Dependents  \
# 15   49           0                1          0                 4
# 51   49           0                1          0                 3
# 54   41           0                1          1                 2
# 79   45           0                1          0                 2
# 81   44           1                1          1                 2
# 91   36           0                1          0                 3
# 95   50           0                1          0                 3
#
#     Personal loan  House Loan  Wife Working   Salary  Wife Salary  \
# 15              1           0             1  2500000      2000000
# 51              1           0             1  2500000      1800000
# 54              1           0             1  2900000      1800000
# 79              1           1             1  2700000      1800000
# 81              1           0             1  3100000      2100000
# ...

# %% [markdown]
# **Principle

# %%
pca = PCA(n_components=2)
data = pca.fit_transform(data)

# Apply K-Means
kmeans = KMeans(n_clusters=4, random_state=0)
kmeans.fit(data)
labels = kmeans.labels_


plt.figure(figsize=(8, 6))
plt.scatter(data[:, 0], data[:, 1], c=labels, cmap='viridis', s=50, alpha=0.7)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], c='red', marker='X', s=200, label='Centroids')
plt.title('K-Means Clustering Visualization (PCA)')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend()
plt.show()
